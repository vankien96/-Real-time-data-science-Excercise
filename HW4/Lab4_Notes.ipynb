# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

from urllib.request import urlopen # module to read in HTML
import bs4 # BeautifulSoup: module to parse HTML and XML
import json # 
import datetime as dt # module for manipulating dates and times
import pandas as pd
import numpy as np

# %% [markdown]
# Previously discussed:
#
# * More pandas, matplotlib for exploratory data analysis
# * Brief introduction to numpy and scipy
# * Working on the command line
# * Overview of git and Github

# %% [markdown]
# ## Today, we will discuss the following:
#
# * urllib2 - reads in HTML
# * BeautifulSoup - use to parse HTML and XML code
#     * Reddit
# * JSON examples
#     * World Cup

# %% [markdown]
# # urllib2
#
# [urllib2](https://docs.python.org/2/library/urllib2.html) is a useful module to get information about and retrieving data from the web. The function `urlopen()` opens a URL (similar to opening a file). The file-like object has some of the methods as a file object. For example, to read the entire HTML of the webpage into a single string, use the method `read()`. `readlines()` can read in the text line by line. While `read()` reads in the HTML code and and `close()` closes the URL connection.

# %%
x = urlopen("http://www.jackyle.xyz/2017/11/tim-hieu-ve-contour-moments-trong-xu-ly.html")
htmlSource = x.read()
x.close()

# %%
type(htmlSource)
# Out:
# bytes

# %%
print(htmlSource)
# Out:
# b'<!DOCTYPE html>\n<html class=\'v2\' dir=\'ltr\' xml:lang=\'vi\' xmlns=\'http://www.w3.org/1999/xhtml\' xmlns:b=\'http://www.google.com/2005/gml/b\' xmlns:data=\'http://www.google.com/2005/gml/data\' xmlns:expr=\'http://www.google.com/2005/gml/expr\'>\n<head>\n<link href=\'https://www.blogger.com/static/v1/widgets/2727757643-css_bundle_v2.css\' rel=\'stylesheet\' type=\'text/css\'/>\n<script type=\'text/javascript\'>\n            var adlinkfly_url = \'http://123link.co/\';\n            var adlinkfly_api_token = \'5f0abddec5ed8e3eb6fbde4c5ceaf6975bae72a5\';\n            var adlinkfly_advert = 2;\n            var adlinkfly_exclude_domains = [\'www.jackyle.xyz\', \'www.jackyle.com\'];\n        </script>\n<script src=\'//123link.pw/js/full-page-script.js\'></script>\n<script async=\'async\' src=\'//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js\'></script>\n<script>\n  (adsbygoogle = window.adsbygoogle || []).push({\n    google_ad_client: "ca-pub-6054902504649525",\n    enable_p
# ...

# %% [markdown]
# # BeautifulSoup
#
# Once you have the HTML source code, you have to parse it and clean it up.
#
# [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/bs4/doc/) is a really useful python module for parsing HTML and XML files.  Let's try a few examples.
#
# For this section, we will be working with the HTML code from [Reddit](http://www.reddit.com).

# %%
x = urlopen("http://www.jackyle.xyz/2017/11/tim-hieu-ve-contour-moments-trong-xu-ly.html") # Opens URLS
htmlSource = x.read()
x.close()
print(htmlSource)
# Out:
# b'<!DOCTYPE html>\n<html class=\'v2\' dir=\'ltr\' xml:lang=\'vi\' xmlns=\'http://www.w3.org/1999/xhtml\' xmlns:b=\'http://www.google.com/2005/gml/b\' xmlns:data=\'http://www.google.com/2005/gml/data\' xmlns:expr=\'http://www.google.com/2005/gml/expr\'>\n<head>\n<link href=\'https://www.blogger.com/static/v1/widgets/2727757643-css_bundle_v2.css\' rel=\'stylesheet\' type=\'text/css\'/>\n<script type=\'text/javascript\'>\n            var adlinkfly_url = \'http://123link.co/\';\n            var adlinkfly_api_token = \'5f0abddec5ed8e3eb6fbde4c5ceaf6975bae72a5\';\n            var adlinkfly_advert = 2;\n            var adlinkfly_exclude_domains = [\'www.jackyle.xyz\', \'www.jackyle.com\'];\n        </script>\n<script src=\'//123link.pw/js/full-page-script.js\'></script>\n<script async=\'async\' src=\'//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js\'></script>\n<script>\n  (adsbygoogle = window.adsbygoogle || []).push({\n    google_ad_client: "ca-pub-6054902504649525",\n    enable_p
# ...

# %% [markdown]
# ### prettify()
#
# Beautiful Soup gives us a `BeautifulSoup` object, which represents the document as a nested data structure. We can use the `prettify()` function to show the different levels of the HTML code.

# %%
soup = bs4.BeautifulSoup(htmlSource)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="v2" dir="ltr" xml:lang="vi" xmlns="http://www.w3.org/1999/xhtml" xmlns:b="http://www.google.com/2005/gml/b" xmlns:data="http://www.google.com/2005/gml/data" xmlns:expr="http://www.google.com/2005/gml/expr">
#  <head>
#   <link href="https://www.blogger.com/static/v1/widgets/2727757643-css_bundle_v2.css" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    var adlinkfly_url = 'http://123link.co/';
#             var adlinkfly_api_token = '5f0abddec5ed8e3eb6fbde4c5ceaf6975bae72a5';
#             var adlinkfly_advert = 2;
#             var adlinkfly_exclude_domains = ['www.jackyle.xyz', 'www.jackyle.com'];
#   </script>
#   <script src="//123link.pw/js/full-page-script.js">
#   </script>
#   <script async="async" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script>
#    (adsbygoogle = window.adsbygoogle || []).push({
#     google_ad_client: "ca-pub-6054902504649525",
# ...

# %% [markdown]
# ### Navigating the tree using tags
#
# The simplest way to navigate the parse tree is to say the name of the tag you want. If you want the `<head>` tag, just say `soup.head`:

# %%
print(soup.head.prettify())
# Out:
# <head>
#  <link href="https://www.blogger.com/static/v1/widgets/2727757643-css_bundle_v2.css" rel="stylesheet" type="text/css"/>
#  <script type="text/javascript">
#   var adlinkfly_url = 'http://123link.co/';
#             var adlinkfly_api_token = '5f0abddec5ed8e3eb6fbde4c5ceaf6975bae72a5';
#             var adlinkfly_advert = 2;
#             var adlinkfly_exclude_domains = ['www.jackyle.xyz', 'www.jackyle.com'];
#  </script>
#  <script src="//123link.pw/js/full-page-script.js">
#  </script>
#  <script async="async" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#  </script>
#  <script>
#   (adsbygoogle = window.adsbygoogle || []).push({
#     google_ad_client: "ca-pub-6054902504649525",
#     enable_page_level_ads: true
#   });
#  </script>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <meta content="blogger" name="generator"/>
#  <link href="http://www.jackyle.xyz/favicon.ico" rel="icon" type="image/x-icon"/>
# ...

# %% [markdown]
# ### .contents and .children
#
# A tag’s children are available in a list called `.contents` which returns a list.

# %%
soup.head.contents
# Out:
# ['\n',
#  <link href="https://www.blogger.com/static/v1/widgets/2727757643-css_bundle_v2.css" rel="stylesheet" type="text/css"/>,
#  '\n',
#  <script type="text/javascript">
#              var adlinkfly_url = 'http://123link.co/';
#              var adlinkfly_api_token = '5f0abddec5ed8e3eb6fbde4c5ceaf6975bae72a5';
#              var adlinkfly_advert = 2;
#              var adlinkfly_exclude_domains = ['www.jackyle.xyz', 'www.jackyle.com'];
#          </script>,
#  '\n',
#  <script src="//123link.pw/js/full-page-script.js"></script>,
#  '\n',
#  <script async="async" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>,
#  '\n',
#  <script>
#    (adsbygoogle = window.adsbygoogle || []).push({
#      google_ad_client: "ca-pub-6054902504649525",
#      enable_page_level_ads: true
#    });
#  </script>,
#  '\n',
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>,
#  '\n',
#  <meta content="blogger" name="generator"/>,
#  '\n',
# ...

# %%
len(soup.head.contents)
# Out:
# 80

# %%
# Extract first three elements from the list of contents
soup.head.contents[0:3]
# Out:
# ['\n',
#  <link href="https://www.blogger.com/static/v1/widgets/2727757643-css_bundle_v2.css" rel="stylesheet" type="text/css"/>,
#  '\n']

# %% [markdown]
# Instead of getting them as a list, you can iterate over a tag’s children using the .children generator:

# %%
soup.head.children

# %%
for child in soup.head.children:
    print(child)
# Out:
# <link href="https://www.blogger.com/static/v1/widgets/2727757643-css_bundle_v2.css" rel="stylesheet" type="text/css"/>
#
#
# <script type="text/javascript">
#             var adlinkfly_url = 'http://123link.co/';
#             var adlinkfly_api_token = '5f0abddec5ed8e3eb6fbde4c5ceaf6975bae72a5';
#             var adlinkfly_advert = 2;
#             var adlinkfly_exclude_domains = ['www.jackyle.xyz', 'www.jackyle.com'];
#         </script>
#
#
# <script src="//123link.pw/js/full-page-script.js"></script>
#
#
# <script async="async" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#
#
# <script>
#   (adsbygoogle = window.adsbygoogle || []).push({
#     google_ad_client: "ca-pub-6054902504649525",
#     enable_page_level_ads: true
#   });
# </script>
#
#
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#
#
# <meta content="blogger" name="generator"/>
#
#
# <link href="http://www.jackyle.xyz/favicon.ico" rel="icon" type="image/x-icon"/>
#
#
# ...

# %%
# print the title of reddit
soup.head.title
# Out:
# <title>
# Tìm hiểu về Contour, moments trong xử lý ảnh - Cộng Đồng OpenCV
# </title>

# %%
# print the string in the title
soup.head.title.string
# Out:
# '\nTìm hiểu về Contour, moments trong xử lý ảnh - Cộng Đồng OpenCV\n'

# %% [markdown]
# ### .descendants
#
# Attribute lets you iterate over all of a tag’s children, recursively: its direct children, the children of its direct children, and so on:

# %%
for child in soup.head.descendants:
    print(child)
# Out:
# <link href="https://www.blogger.com/static/v1/widgets/2727757643-css_bundle_v2.css" rel="stylesheet" type="text/css"/>
#
#
# <script type="text/javascript">
#             var adlinkfly_url = 'http://123link.co/';
#             var adlinkfly_api_token = '5f0abddec5ed8e3eb6fbde4c5ceaf6975bae72a5';
#             var adlinkfly_advert = 2;
#             var adlinkfly_exclude_domains = ['www.jackyle.xyz', 'www.jackyle.com'];
#         </script>
#
#             var adlinkfly_url = 'http://123link.co/';
#             var adlinkfly_api_token = '5f0abddec5ed8e3eb6fbde4c5ceaf6975bae72a5';
#             var adlinkfly_advert = 2;
#             var adlinkfly_exclude_domains = ['www.jackyle.xyz', 'www.jackyle.com'];
#
#
#
# <script src="//123link.pw/js/full-page-script.js"></script>
#
#
# <script async="async" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#
#
# <script>
#   (adsbygoogle = window.adsbygoogle || []).push({
#     google_ad_client: "ca-pub-6054902504649525",
# ...

# %% [markdown]
# ### .strings
#
# If there’s more than one thing inside a tag, you can still look at just the strings. Use the .strings generator

# %%
for string in soup.strings:
    print(repr(string))
# Out:
# '\n'
# '\n'
# '\n'
# "\n            var adlinkfly_url = 'http://123link.co/';\n            var adlinkfly_api_token = '5f0abddec5ed8e3eb6fbde4c5ceaf6975bae72a5';\n            var adlinkfly_advert = 2;\n            var adlinkfly_exclude_domains = ['www.jackyle.xyz', 'www.jackyle.com'];\n        "
# '\n'
# '\n'
# '\n'
# '\n  (adsbygoogle = window.adsbygoogle || []).push({\n    google_ad_client: "ca-pub-6054902504649525",\n    enable_page_level_ads: true\n  });\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\nTìm hiểu về Contour, moments trong xử lý ảnh - Cộng Đồng OpenCV\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# ...

# %% [markdown]
# ### .stripped_strings
#
# These strings tend to have a lot of extra whitespace, which you can remove by using the .stripped_strings generator instead

# %%
for string in soup.stripped_strings:
    print(repr(string))
# Out:
# "var adlinkfly_url = 'http://123link.co/';\n            var adlinkfly_api_token = '5f0abddec5ed8e3eb6fbde4c5ceaf6975bae72a5';\n            var adlinkfly_advert = 2;\n            var adlinkfly_exclude_domains = ['www.jackyle.xyz', 'www.jackyle.com'];"
# '(adsbygoogle = window.adsbygoogle || []).push({\n    google_ad_client: "ca-pub-6054902504649525",\n    enable_page_level_ads: true\n  });'
# 'Tìm hiểu về Contour, moments trong xử lý ảnh - Cộng Đồng OpenCV'
# ...

# %% [markdown]
# ### .parent
#
# You can access an element’s parent with the `.parent` attribute. In the example “three sisters” document, the `<head>` tag is the parent of the `<title>` tag:

# %%
soup.title

# %%
soup.title.string

# %%
soup.title.string.parent

# %% [markdown]
# # Searching the Tree
#
# Now, let's consider examples of different filters you can use to search this nested tree of HTML. These filters show up again and again, throughout the search API. You can use them to filter based on a tag’s name, on its attributes, on the text of a string, or on some combination of these.
#
# #### Use `find_all()` to find all tags

# %% [markdown]
# One common task is extracting all the URLs found within a page's tags:

# %%
# search for all <a> tags; returns a list
soup.find_all('a')
# Out:
# [<a href="p/about.html">Giới thiệu</a>,
#  <a class="facebook" href="https://www.facebook.com/congdongopencv/" title="facebook"></a>,
#  <a class="youtube" href="https://www.youtube.com/jackyle" title="youtube"></a>,
#  <a class="gplus" href="https://plus.google.com/" title="gplus"></a>,
#  <a class="twitter" href="https://twitter.com/" title="twitter"></a>,
#  <a href="http://www.jackyle.xyz/">Cộng Đồng OpenCV</a>,
#  <a class="quickedit" href="//www.blogger.com/rearrange?blogID=7823456543153232903&amp;widgetType=HTML&amp;widgetId=HTML222&amp;action=editWidget&amp;sectionId=topad" onclick='return _WidgetManager._PopupConfig(document.getElementById("HTML222"));' target="configHTML222" title="Chỉnh sửa">
#  <img alt="" height="18" src="https://resources.blogblog.com/img/icon18_wrench_allbkg.png" width="18"/>
#  </a>,
#  <a class="home-icon" href="http://www.jackyle.xyz/"><i class="fa fa-home"></i>
#  </a>,
# ...

# %%
# your turn
# search for all the paragragh tags
soup.findAll('p')
# Out:
# [<p class="description"><span>Youtube.com/jackyle</span></p>,
#  <p class="tagstitle">Từ khóa :</p>,
#  <p class="comment-footer">
#  </p>,
#  <p>
#  </p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p class="contact-form-error-message" id="ContactForm1_contact-form-error-message"></p>,
#  <p class="contact-form-success-message" id="ContactForm1_contact-form-success-message"></p>,
#  <p class="contact-form-error-message" id="ContactForm10_contact-form-error-message"></p>,
#  <p class="contact-form-success-message" id="ContactForm10_contact-form-success-message"></p>]

# %%
# your turn
# search for all the table tags
soup.findAll('table')
# Out:
# [<table cellpadding="0" cellspacing="0" class="gsc-search-box">
#  <tbody>
#  <tr>
#  <td class="gsc-input">
#  <input autocomplete="off" class="gsc-input" name="q" size="10" title="search" type="text" value=""/>
#  </td>
#  <td class="gsc-search-button">
#  <input class="gsc-search-button" title="search" type="submit" value="Tìm kiếm"/>
#  </td>
#  </tr>
#  </tbody>
#  </table>]

# %% [markdown]
# Other arguments to the `.find_all()` function include `limit` and `text`. What do those do?

# %%
# your turn 
# search for all the <a> tags and use the limit argument 
soup.findAll('a',limit=10, text='Giới thiệu')
# Out:
# [<a href="p/about.html">Giới thiệu</a>]

# %%
# your turn 
# What does the using the text argument do? 
# text argument to filter text inside tag we use to find

# %% [markdown]
# #### Use `.get()` to extract an attribute

# %%
soup.find_all('a')[1].get('href')
# Out:
# 'https://www.facebook.com/congdongopencv/'

# %% [markdown]
# #### Looping through tags

# %%
# your turn
# write a for loop printing all the links from web

for item in soup.findAll():
    if item.get('href') != None:
        print(item.get('href'))
# Out:
# https://www.blogger.com/static/v1/widgets/2727757643-css_bundle_v2.css
# http://www.jackyle.xyz/favicon.ico
# http://www.jackyle.xyz/2017/11/tim-hieu-ve-contour-moments-trong-xu-ly.html
# http://www.jackyle.xyz/feeds/posts/default
# http://www.jackyle.xyz/feeds/posts/default?alt=rss
# https://www.blogger.com/feeds/7823456543153232903/posts/default
# http://www.jackyle.xyz/feeds/2546821837501230764/comments/default
# https://univtechnews.files.wordpress.com/2017/04/untitled14.png?w=736
# https://www.blogger.com/dyn-css/authorization.css?targetBlogID=7823456543153232903&zx=c46fdd9c-572b-4417-a40a-ae010134626c
# https://www.blogger.com/dyn-css/authorization.css?targetBlogID=7823456543153232903&zx=c46fdd9c-572b-4417-a40a-ae010134626c
# p/about.html
# https://www.facebook.com/congdongopencv/
# https://www.youtube.com/jackyle
# https://plus.google.com/
# https://twitter.com/
# http://www.jackyle.xyz/
# ...

# %%
# your turn
# write a for loop, but use a list comprehension this time
# show the first 5 elements
i = 0
for item in soup.findAll():
    if (item.get('href') != None) and (i < 5):
        print(item.get('href'))
        i += 1
# Out:
# https://www.blogger.com/static/v1/widgets/2727757643-css_bundle_v2.css
# http://www.jackyle.xyz/favicon.ico
# http://www.jackyle.xyz/2017/11/tim-hieu-ve-contour-moments-trong-xu-ly.html
# http://www.jackyle.xyz/feeds/posts/default
# http://www.jackyle.xyz/feeds/posts/default?alt=rss

# %%
# your turn
# split the first url by "/"
firstUrl = ""
for item in soup.findAll():
    if (item.get('href') != None):
        firstUrl = item.get('href')
        break
firstUrl.split('/')
# Out:
# ['https:',
#  '',
#  'www.blogger.com',
#  'static',
#  'v1',
#  'widgets',
#  '2727757643-css_bundle_v2.css']

# %% [markdown]
# Another common task is extracting all the text from a page:

# %%
print(soup.get_text())
# Out:
#             var adlinkfly_url = 'http://123link.co/';
#             var adlinkfly_api_token = '5f0abddec5ed8e3eb6fbde4c5ceaf6975bae72a5';
#             var adlinkfly_advert = 2;
#             var adlinkfly_exclude_domains = ['www.jackyle.xyz', 'www.jackyle.com'];
#
#
#
#
#   (adsbygoogle = window.adsbygoogle || []).push({
#     google_ad_client: "ca-pub-6054902504649525",
#     enable_page_level_ads: true
#   });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Tìm hiểu về Contour, moments trong xử lý ảnh - Cộng Đồng OpenCV
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--
# .fa,.big,#HTML6,.st-social,st-cmt,.sticky-spacer,.theiaStickySidebar,.snowfall-flakes{transition:all 0s ease;-webkit-transition:all 0s ease;-moz-transition:all 0s ease;-o-transition:all 0s ease}
# *{outline:0;transition:all .3s ease;-webkit-transition:all .3s ease;-moz-transition:all .3s ease;-o-transition:all .3s ease}
# *,:before,:after{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}
# ...

# %% [markdown]
# # JSON
#
# #### Working with Web APIs
# Web APIs are a more convenient way for programs to interact with websites. Many webistes now have a nice API that gives access to it's data in JSON format.

# %%
a = {'a': 1, 'b':2}
s = json.dumps(a)
a2 = json.loads(s)

# %%
a # a dictionary
# Out:
# {'a': 1, 'b': 2}

# %%
s # s is a string containing a in JSON encoding
# Out:
# '{"a": 1, "b": 2}'

# %%
a2 # reading back the keys are now in unicode
# Out:
# {'a': 1, 'b': 2}

# %% [markdown]
# ## World Cup in JSON!
#
# The [2014 FIFA World Cup](http://en.wikipedia.org/wiki/2014_FIFA_World_Cup) was held this summer in Brazil at several different venues.  There was an [API created for the World Cup](http://worldcup.sfg.io) that scraped current match results and output match data as JSON. Possible output includes events such as goals, substitutions, and cards. The [actual matches are listed here](http://worldcup.sfg.io/matches) in JSON.
#
# * Example from [Fernando Masanori](https://gist.github.com/fmasanori/1288160dad16cc473a53)

# %%
url = "http://worldcup.sfg.io/matches"
data = urlopen(url).read()
wc = json.loads(data.decode('utf-8'))

# %%
"Number of matches in 2018 World Cup: %i" % len(wc)
# Out:
# 'Number of matches in 2018 World Cup: 64'

# %%
# Print keys in first match
gameIndex = 60
wc[gameIndex].keys()
# Out:
# dict_keys(['venue', 'location', 'status', 'time', 'fifa_id', 'weather', 'attendance', 'officials', 'stage_name', 'home_team_country', 'away_team_country', 'datetime', 'winner', 'winner_code', 'home_team', 'away_team', 'home_team_events', 'away_team_events', 'home_team_statistics', 'away_team_statistics', 'last_event_update_at', 'last_score_update_at'])

# %%
wc[gameIndex]['status']
# Out:
# 'completed'

# %%
wc[gameIndex]['location']
# Out:
# 'Saint Petersburg Stadium'

# %%
wc[gameIndex]['away_team']
# Out:
# {'country': 'Belgium', 'code': 'BEL', 'goals': 0, 'penalties': 0}

# %%
wc[gameIndex]['away_team_events']
# Out:
# [{'id': 1122,
#   'type_of_event': 'substitution-out',
#   'player': 'Moussa DEMBELE',
#   'time': "60'"},
#  {'id': 1123,
#   'type_of_event': 'substitution-in',
#   'player': 'Dries MERTENS',
#   'time': "60'"},
#  {'id': 1124,
#   'type_of_event': 'yellow-card',
#   'player': 'Eden HAZARD',
#   'time': "63'"},
#  {'id': 1125,
#   'type_of_event': 'yellow-card',
#   'player': 'Toby ALDERWEIRELD',
#   'time': "71'"},
#  {'id': 1126,
#   'type_of_event': 'substitution-out',
#   'player': 'Marouane FELLAINI',
#   'time': "80'"},
#  {'id': 1127,
#   'type_of_event': 'substitution-in',
#   'player': 'Yannick CARRASCO',
#   'time': "80'"},
#  {'id': 1134,
#   'type_of_event': 'substitution-out',
#   'player': 'Nacer CHADLI',
#   'time': "90'+1'"},
#  {'id': 1135,
#   'type_of_event': 'substitution-in',
#   'player': 'Michy BATSHUAYI',
#   'time': "90'+1'"},
#  {'id': 1136,
#   'type_of_event': 'yellow-card',
#   'player': 'Jan VERTONGHEN',
#   'time': "90'+4'"}]

# %%
wc[gameIndex]['home_team']
# Out:
# {'country': 'France', 'code': 'FRA', 'goals': 1, 'penalties': 0}

# %% [markdown]
# The [Brazil v Germany (2014 FIFA World Cup)](http://en.wikipedia.org/wiki/Brazil_v_Germany_(2014_FIFA_World_Cup) match on July 8, 2014 where Germany score the most goals in World Cup tournament history.  Germany led 5–0 at half time, with 4 goals scored in a span of 6 minutes, and subsequently brought the score up to 7–0 in the second half. Brazil scored a goal at the last minute, ending the match 7–1.

# %% [markdown]
# Print the team names and goals scored for each match

# %%
for elem in wc:
    print(elem['home_team']['country'], elem['home_team']['goals'], elem['away_team']['country'], elem['away_team']['goals'])
# Out:
# Russia 5 Saudi Arabia 0
# Egypt 0 Uruguay 1
# Morocco 0 Iran 1
# Portugal 3 Spain 3
# France 2 Australia 1
# Argentina 1 Iceland 1
# Peru 0 Denmark 1
# Croatia 2 Nigeria 0
# Costa Rica 0 Serbia 1
# Germany 0 Mexico 1
# Brazil 1 Switzerland 1
# Sweden 1 Korea Republic 0
# Belgium 3 Panama 0
# Tunisia 1 England 2
# Colombia 1 Japan 2
# Poland 1 Senegal 2
# Russia 3 Egypt 1
# Portugal 1 Morocco 0
# Uruguay 1 Saudi Arabia 0
# Iran 0 Spain 1
# Denmark 1 Australia 1
# France 1 Peru 0
# Argentina 0 Croatia 3
# Brazil 2 Costa Rica 0
# Nigeria 2 Iceland 0
# Serbia 1 Switzerland 2
# Belgium 5 Tunisia 2
# Korea Republic 1 Mexico 2
# Germany 2 Sweden 1
# England 6 Panama 1
# Japan 2 Senegal 2
# Poland 0 Colombia 3
# Uruguay 3 Russia 0
# Saudi Arabia 2 Egypt 1
# Spain 2 Morocco 2
# Iran 1 Portugal 1
# Denmark 0 France 0
# Australia 0 Peru 2
# Iceland 1 Croatia 2
# Nigeria 1 Argentina 2
# Korea Republic 2 Germany 0
# Mexico 0 Sweden 3
# Switzerland 2 Costa Rica 2
# Serbia 0 Brazil 2
# ...

# %% [markdown]
# ### Create a pandas DataFrame from JSON

# %%
data = pd.DataFrame(wc, columns = ['location', 'datetime', 'home_team', 'away_team', 'winner', 'home_team_events', 'away_team_events'])
data.head()
# Out:
#                    location              datetime  \
# 0          Luzhniki Stadium  2018-06-14T15:00:00Z
# 1        Ekaterinburg Arena  2018-06-15T12:00:00Z
# 2  Saint Petersburg Stadium  2018-06-15T15:00:00Z
# 3             Fisht Stadium  2018-06-15T18:00:00Z
# 4               Kazan Arena  2018-06-16T10:00:00Z
#
#                                            home_team  \
# 0  {'country': 'Russia', 'code': 'RUS', 'goals': ...
# 1  {'country': 'Egypt', 'code': 'EGY', 'goals': 0...
# 2  {'country': 'Morocco', 'code': 'MAR', 'goals':...
# 3  {'country': 'Portugal', 'code': 'POR', 'goals'...
# 4  {'country': 'France', 'code': 'FRA', 'goals': ...
#
#                                            away_team   winner  \
# 0  {'country': 'Saudi Arabia', 'code': 'KSA', 'go...   Russia
# 1  {'country': 'Uruguay', 'code': 'URU', 'goals':...  Uruguay
# 2  {'country': 'Iran', 'code': 'IRN', 'goals': 1,...     Iran
# 3  {'country': 'Spain', 'code': 'ESP', 'goals': 3...     Draw
# ...

# %% [markdown]
# #### Convert format of a column
#
# Here we pandas [DatetimeIndex](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DatetimeIndex.html) to convert the `datetime` column to two seperate columns: a date and a time for each match.

# %%
data['gameDate'] = pd.DatetimeIndex(data.datetime).date
data['gameTime'] = pd.DatetimeIndex(data.datetime).time

# %%
data.head()
# Out:
#                    location              datetime  \
# 0          Luzhniki Stadium  2018-06-14T15:00:00Z
# 1        Ekaterinburg Arena  2018-06-15T12:00:00Z
# 2  Saint Petersburg Stadium  2018-06-15T15:00:00Z
# 3             Fisht Stadium  2018-06-15T18:00:00Z
# 4               Kazan Arena  2018-06-16T10:00:00Z
#
#                                            home_team  \
# 0  {'country': 'Russia', 'code': 'RUS', 'goals': ...
# 1  {'country': 'Egypt', 'code': 'EGY', 'goals': 0...
# 2  {'country': 'Morocco', 'code': 'MAR', 'goals':...
# 3  {'country': 'Portugal', 'code': 'POR', 'goals'...
# 4  {'country': 'France', 'code': 'FRA', 'goals': ...
#
#                                            away_team   winner  \
# 0  {'country': 'Saudi Arabia', 'code': 'KSA', 'go...   Russia
# 1  {'country': 'Uruguay', 'code': 'URU', 'goals':...  Uruguay
# 2  {'country': 'Iran', 'code': 'IRN', 'goals': 1,...     Iran
# 3  {'country': 'Spain', 'code': 'ESP', 'goals': 3...     Draw
# ...
